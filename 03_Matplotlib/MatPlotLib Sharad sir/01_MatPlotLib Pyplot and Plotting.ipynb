# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,8])
ypoints = np.array([3,8])
plt.plot(xpoints, ypoints)
plt.show()

# %%
# without line
x = np.array([1,8])
y = np.array([3,8])
plt.plot(x, y, 'r o')
plt.show()

# %%
x = np.array([1,2,5,3,1,3,8,1,8])
y = np.array([3,6,1,9,3,7,1,5,8])
plt.plot(x, y)
plt.show()

# %%
# default X -points
y = np.array([3,2,6,1,7])
plt.plot(y)
plt.show()

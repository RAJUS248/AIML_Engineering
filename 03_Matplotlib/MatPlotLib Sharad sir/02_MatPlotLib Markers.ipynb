# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([3,4,5,1,10])
# plt.plot(y, marker = 'o', linestyle = '--',color = 'r')
# or
plt.plot(y, 'o--r', ms = 20 , mec= 'k', mfc = 'b' ) # marker size and mec is marker color mfc marker face color
plt.show()

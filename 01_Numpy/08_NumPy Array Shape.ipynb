# %% [markdown]
# # shape of an array - it is the num of elm in each dimension

# %% [markdown]
# # get the shape

# %%
import numpy as np
arr = np.array([[1,2,3],[4,5,6]])
print(arr.shape)
# Out:
# (2, 3)

# %%
arr = np.array([1,2,3,4], ndmin=5)
print(arr)
print(arr.shape)
# Out:
# [[[[[1 2 3 4]]]]]
# (1, 1, 1, 1, 4)
